# %% [markdown]
# ##DELTA LIVE TABLES - DLT

# %% [markdown]
# ###Expectations

# %%
Expec_coaches = {
    "rule1":"code is not null",
    "rule2":"current is True"
}

# %%
Expec_nocs = {
    "rule1":"code is not null"
}

# %%
Expec_events = {
    "rule1":"event is not null"
}

# %% [markdown]
# **Coaches DLT pipline**

# %%
import dlt
from pyspark.sql.functions import *

# %%
@dlt.table

@dlt.expect_all(Expec_coaches)
def source_coaches():
    df = spark.readStream.table("olympics.silver.coaches")
    return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>source_coaches</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>current</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>gender</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>function</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>category</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_long</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>disciplines</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>events</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>birth_date</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4500566397059421#joblist/pipelines/create?initialSource=%2FUsers%2Fmounikapeddinti1997%40outlook.com%2FOlympics%2FGold%20Layer%20or%20Curated_Entities&redirectNotebookId=3248952838365683">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.view

def view_coaches():
    df = spark.readStream.table("LIVE.source_coaches")
    return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>view_coaches</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>current</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>gender</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>function</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>category</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_long</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>disciplines</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>events</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>birth_date</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4500566397059421#joblist/pipelines/create?initialSource=%2FUsers%2Fmounikapeddinti1997%40outlook.com%2FOlympics%2FGold%20Layer%20or%20Curated_Entities&redirectNotebookId=3248952838365683">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table

def coaches():
    df = spark.readStream.table("LIVE.view_coaches")
    return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>coaches</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>current</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>gender</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>function</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>category</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_long</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>disciplines</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>events</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>birth_date</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4500566397059421#joblist/pipelines/create?initialSource=%2FUsers%2Fmounikapeddinti1997%40outlook.com%2FOlympics%2FGold%20Layer%20or%20Curated_Entities&redirectNotebookId=3248952838365683">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %% [markdown]
# **NOCS DLT pipeline**

# %%
@dlt.view

def source_nocs():
    df = spark.readStream.table("olympics.silver.nocs")
    return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>source_nocs</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_long</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>tag</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>note</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4500566397059421#joblist/pipelines/create?initialSource=%2FUsers%2Fmounikapeddinti1997%40outlook.com%2FOlympics%2FGold%20Layer%20or%20Curated_Entities&redirectNotebookId=3248952838365683">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table

@dlt.expect_all_or_drop(Expec_nocs)
def nocs():
    df = spark.readStream.table("LIVE.source_nocs")
    return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>nocs</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_long</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>tag</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>note</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4500566397059421#joblist/pipelines/create?initialSource=%2FUsers%2Fmounikapeddinti1997%40outlook.com%2FOlympics%2FGold%20Layer%20or%20Curated_Entities&redirectNotebookId=3248952838365683">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %% [markdown]
# **Events DLT pipeline**

# %%
@dlt.view

def source_events():
    df = spark.readStream.table("olympics.silver.events")
    return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>source_events</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>event</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>tag</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>sport</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>sport_code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>sport_url</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4500566397059421#joblist/pipelines/create?initialSource=%2FUsers%2Fmounikapeddinti1997%40outlook.com%2FOlympics%2FGold%20Layer%20or%20Curated_Entities&redirectNotebookId=3248952838365683">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table

@dlt.expect_all(Expec_events)
def events():
    df = spark.readStream.table("LIVE.source_events")
    return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>events</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>event</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>tag</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>sport</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>sport_code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>sport_url</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4500566397059421#joblist/pipelines/create?initialSource=%2FUsers%2Fmounikapeddinti1997%40outlook.com%2FOlympics%2FGold%20Layer%20or%20Curated_Entities&redirectNotebookId=3248952838365683">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %% [markdown]
# ###CDC - Applying DLT

# %%
@dlt.view

def source_athletes():
    df = spark.readStream.table("olympics.silver.athletes")
    return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>source_athletes</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>athleteID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>current</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>name_short</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>name_tv</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>gender</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>function</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_long</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>nationality</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>nationality_long</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>nationality_code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>height</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>weight</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>disciplines</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>events</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>birth_date</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>birth_place</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>birth_country</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4500566397059421#joblist/pipelines/create?initialSource=%2FUsers%2Fmounikapeddinti1997%40outlook.com%2FOlympics%2FGold%20Layer%20or%20Curated_Entities&redirectNotebookId=3248952838365683">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
dlt.create_streaming_table("athletes")
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>athletes</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
# .
# </div>
#
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4500566397059421#joblist/pipelines/create?initialSource=%2FUsers%2Fmounikapeddinti1997%40outlook.com%2FOlympics%2FGold%20Layer%20or%20Curated_Entities&redirectNotebookId=3248952838365683">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
dlt.apply_changes(
    target = "athletes",
    source = "source_athletes",
    keys = ["athleteID"],
    sequence_by = col("height"),
     stored_as_scd_type = 1

)
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>athletes</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>athleteID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>current</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>name_short</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>name_tv</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>gender</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>function</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>country_long</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>nationality</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>nationality_long</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>nationality_code</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>height</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>weight</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>disciplines</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>events</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>birth_date</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>birth_place</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>birth_country</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4500566397059421#joblist/pipelines/create?initialSource=%2FUsers%2Fmounikapeddinti1997%40outlook.com%2FOlympics%2FGold%20Layer%20or%20Curated_Entities&redirectNotebookId=3248952838365683">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>
